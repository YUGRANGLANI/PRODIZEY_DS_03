# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
ds=pd.read_csv(r'bank-additional (1).csv',delimiter=';')

# %%
ds.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
ds.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
ds.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
ds.duplicated().sum()
# Out:
# np.int64(0)

# %%
ds.shape
# Out:
# (4119, 21)

# %%
ds.hist(figsize=(10,10),color='skyblue')
plt.show()

# %%
ds[ds['age'] ==30].sum()
# Out:
# age                                                            5310
# job               blue-collarblue-collarblue-collaradmin.blue-co...
# marital           marriedsinglesinglemarriedsinglesinglemarrieds...
# education         basic.9ybasic.4ybasic.6yhigh.schoolbasic.9ybas...
# default           nounknownnounknownnounknownnononononononounkno...
# housing           yesyesyesyesnoyesnoyesnoyesyesnoyesyesnononono...
# loan              nonononononononononononononononononononononono...
# contact           cellulartelephonetelephonecellularcellulartele...
# month             mayjunjulnovnovjunmayaugmayjuljuljunnovmaymayn...
# day_of_week       frituetuewedwedwedwedmonfriwedtuemontuewedtuet...
# duration                                                      39359
# campaign                                                        470
# pdays                                                        168892
# previous                                                         32
# ...

# %%
plt.figure(figsize=(19, 6))
sns.histplot(ds['job'])
# Out:
# <Axes: xlabel='job', ylabel='Count'>

# %%
plt.figure(figsize=(8, 5))
sns.histplot(ds['age'],color='y')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))  
sns.barplot(ds['marital'].value_counts())
plt.show()

# %%
plt.figure(figsize=(10,5))  
sns.barplot(ds['education'].value_counts())
plt.show()

# %%
plt.plot(ds['default'].value_counts())
plt.show()

# %%
sns.barplot(ds['housing'].value_counts())
plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)   
sns.barplot(ds['loan'].value_counts(),ax=ax1, palette='deep')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
sns.barplot(ds['month'].value_counts(), ax=ax2, palette='deep')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_4792\2317000782.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ds['loan'].value_counts(),ax=ax1, palette='deep')
# C:\Users\pc\AppData\Local\Temp\ipykernel_4792\2317000782.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# C:\Users\pc\AppData\Local\Temp\ipykernel_4792\2317000782.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ds['month'].value_counts(), ax=ax2, palette='deep')
# ...

# %%
 sns.barplot(ds['day_of_week'].value_counts())
plt.show()

# %%
ds.plot.box(subplots=True, layout=(2, 5), figsize=(20, 10), color='#7b3f00')
plt.show()
